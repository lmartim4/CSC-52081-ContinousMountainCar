# %% [markdown]
# # 04 — PPO with Symbolic Grid Observations
# Train a PPO agent using a tile-based symbolic grid.

# %%
# --- Google Colab Setup ---
import os, sys

if os.getenv('COLAB_RELEASE_TAG'):
    # !pip install -q Cython setuptools wheel
    # !git clone -b hotfix/version1 https://github.com/lmartim4/CSC-52081-ContinousMountainCar.git /content/repo
    # %cd /content/repo
    # !pip install -r requirements.txt --no-build-isolation
    sys.path.insert(0, '/content/repo')
    import site; SITE = site.getsitepackages()[0]
    # !patch --forward -p0 {SITE}/nes_py/_rom.py                   < patches/nes_py_numpy2.patch || true
    # !patch --forward -p0 {SITE}/gym/utils/passive_env_checker.py < patches/gym_bool8_numpy2.patch || true
    # !patch --forward -p0 {SITE}/gym_super_mario_bros/smb_env.py  < patches/smb_env_numpy2.patch || true
    # !sed -i 's/observation, reward, terminated, truncated, info = self.env.step(action)/_result = self.env.step(action); observation, reward, terminated, info = _result[:4]; truncated = _result[4] if len(_result) > 4 else False/' {SITE}/gym/wrappers/time_limit.py
else:
    if os.path.basename(os.getcwd()) == 'notebooks':
        # %cd ..
# Out:
# /home/contente/Documents/ENSTA/autonomous/CSC-52081-ContinousMountainCar

# %%
from src.wrappers import make_symbolic_env
from src.agents import make_ppo_agent
from src.utils.callbacks import CheckpointAndLogCallback
from src.config import PPOConfig
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Create environment
env = make_symbolic_env(flatten=True)
print(f'Observation space: {env.observation_space.shape}')
print(f'Action space: {env.action_space.n}')
# Out:
# Observation space: (832,)
# Action space: 7

# %%
# Configure for MLP policy
config = PPOConfig(total_timesteps=2_000_000, policy='MlpPolicy')
model = make_ppo_agent(env, config=config, tensorboard_log='../logs/symbolic_ppo')
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/contente/miniconda3/envs/mario_lucas/lib/python3.14/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/contente/miniconda3/envs/mario_lucas/lib/python3.14/site-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# /home/contente/miniconda3/envs/mario_lucas/lib/python3.14/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Train
callback = CheckpointAndLogCallback(
    save_path='../models/symbolic_ppo',
    save_freq=100_000,
)
model.learn(total_timesteps=config.total_timesteps, callback=callback)
model.save('../models/symbolic_ppo/final_model')
# Out:
# Logging to ../logs/symbolic_ppo/PPO_1
# /home/contente/miniconda3/envs/mario_lucas/lib/python3.14/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# /home/contente/miniconda3/envs/mario_lucas/lib/python3.14/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 629      |
# | time/              |          |
# |    fps             | 104      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 128      |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 2             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 4.7782436e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00107      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.78e+03      |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.00135      |
# |    value_loss           | 7.62e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 109           |
# |    iterations           | 3             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 384           |
# | train/                  |               |
# |    approx_kl            | 4.4692308e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00132       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 727           |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 1.48e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 113           |
# |    iterations           | 4             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 512           |
# | train/                  |               |
# |    approx_kl            | 3.1861942e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0143        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.12e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.000663     |
# |    value_loss           | 2.27e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | 629          |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 6.663008e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.16         |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 9.93         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 115           |
# |    iterations           | 6             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 8.4595755e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0198        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.53          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00138      |
# |    value_loss           | 9.62          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 115           |
# |    iterations           | 7             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 896           |
# | train/                  |               |
# |    approx_kl            | 0.00012129918 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00988       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.72          |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.0013       |
# |    value_loss           | 10.6          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# |    flag_rate_100        | 0             |
# |    mean_length_100      | 116           |
# |    mean_reward_100      | 629           |
# | time/                   |               |
# |    fps                  | 116           |
# |    iterations           | 8             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 0.00011847168 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0616       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.49          |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.00143      |
# |    value_loss           | 12.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | 629          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 9            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0001556375 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.000464    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.36         |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.000983    |
# |    value_loss           | 7.54         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 10            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 0.00021345355 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 6.04e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.19          |
# |    n_updates            | 36            |
# |    policy_gradient_loss | -0.00209      |
# |    value_loss           | 12            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 11            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 0.00020317687 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0454        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.64          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00179      |
# |    value_loss           | 15.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 12            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 9.2485454e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00691       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.87          |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.000494     |
# |    value_loss           | 6.68          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | 629          |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 13           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0002593426 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.49         |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 15.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 14            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 1792          |
# | train/                  |               |
# |    approx_kl            | 0.00029073423 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00897      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.12          |
# |    n_updates            | 52            |
# |    policy_gradient_loss | -0.000841     |
# |    value_loss           | 5.08          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 15            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 1920          |
# | train/                  |               |
# |    approx_kl            | 0.00033300696 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.0699        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.71          |
# |    n_updates            | 56            |
# |    policy_gradient_loss | -0.00193      |
# |    value_loss           | 4.14          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | 629           |
# |    flag_rate_100        | 0             |
# |    mean_length_100      | 116           |
# |    mean_reward_100      | 629           |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 16            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00031823618 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | -0.0204       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.5           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 18.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.04e+03      |
# |    ep_rew_mean          | 572           |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 17            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 2176          |
# | train/                  |               |
# |    approx_kl            | 0.00016581127 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.0202        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 122           |
# |    n_updates            | 64            |
# |    policy_gradient_loss | 0.000243      |
# |    value_loss           | 243           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.04e+03      |
# |    ep_rew_mean          | 572           |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 18            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 2304          |
# | train/                  |               |
# |    approx_kl            | 5.0051138e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | -0.0104       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.75e+03      |
# |    n_updates            | 68            |
# |    policy_gradient_loss | 0.000332      |
# |    value_loss           | 3.51e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 769          |
# |    ep_rew_mean          | 592          |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 19           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 2432         |
# | train/                  |              |
# |    approx_kl            | 2.986705e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0138       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 984          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -6.44e-05    |
# |    value_loss           | 1.98e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 622           |
# |    ep_rew_mean          | 587           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 20            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 1.5933532e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | -0.00603      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.7e+03       |
# |    n_updates            | 76            |
# |    policy_gradient_loss | 6.93e-05      |
# |    value_loss           | 3.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 534           |
# |    ep_rew_mean          | 597           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 21            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 2688          |
# | train/                  |               |
# |    approx_kl            | 4.0731393e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.00229       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.5e+03       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 3.5e-05       |
# |    value_loss           | 5.02e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 534          |
# |    ep_rew_mean          | 597          |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 22           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 5.051028e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0226       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 436          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000226    |
# |    value_loss           | 881          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 534           |
# |    ep_rew_mean          | 597           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 23            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 2944          |
# | train/                  |               |
# |    approx_kl            | 5.0007366e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.00414       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.43e+03      |
# |    n_updates            | 88            |
# |    policy_gradient_loss | 0.000103      |
# |    value_loss           | 4.9e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 506          |
# |    ep_rew_mean          | 598          |
# |    flag_rate_100        | 0            |
# |    mean_length_100      | 534          |
# |    mean_reward_100      | 597          |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 24           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 1.877267e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.00537      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.74         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000282    |
# |    value_loss           | 6.98         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 506           |
# |    ep_rew_mean          | 598           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 25            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 2.5416724e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.0251        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 956           |
# |    n_updates            | 96            |
# |    policy_gradient_loss | -8.36e-05     |
# |    value_loss           | 1.92e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 506           |
# |    ep_rew_mean          | 598           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 26            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 1.2035016e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.017         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.52e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000168      |
# |    value_loss           | 3.05e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 486           |
# |    ep_rew_mean          | 625           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 27            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 3456          |
# | train/                  |               |
# |    approx_kl            | 7.2520226e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | -0.0301       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 26.9          |
# |    n_updates            | 104           |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 54.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 486           |
# |    ep_rew_mean          | 625           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 28            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 0.00014821906 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.0141        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.09e+03      |
# |    n_updates            | 108           |
# |    policy_gradient_loss | 0.00037       |
# |    value_loss           | 2.18e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 411           |
# |    ep_rew_mean          | 580           |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 29            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 3712          |
# | train/                  |               |
# |    approx_kl            | 4.8757996e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.0191        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 896           |
# |    n_updates            | 112           |
# |    policy_gradient_loss | 0.000253      |
# |    value_loss           | 1.8e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 411          |
# |    ep_rew_mean          | 580          |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 30           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 1.830142e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | -0.00387     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 116          |
# |    policy_gradient_loss | 0.000594     |
# |    value_loss           | 2.06e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 395        |
# |    ep_rew_mean          | 593        |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 31         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 3968       |
# | train/                  |            |
# |    approx_kl            | 9.0627e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.9       |
# |    explained_variance   | 0.00345    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.67e+03   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.000443  |
# |    value_loss           | 7.36e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 370         |
# |    ep_rew_mean          | 595         |
# |    flag_rate_100        | 0           |
# |    mean_length_100      | 395         |
# |    mean_reward_100      | 593         |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 32          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 9.64012e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -0.00144    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 226         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.000274   |
# |    value_loss           | 457         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 595          |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 33           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 8.935574e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | -0.00049     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.95e+03     |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000138    |
# |    value_loss           | 5.91e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 34            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 4.1169114e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.00737       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.81e+03      |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 3.64e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 35            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 4480          |
# | train/                  |               |
# |    approx_kl            | 2.6011374e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | -0.0964       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.61          |
# |    n_updates            | 136           |
# |    policy_gradient_loss | -0.000659     |
# |    value_loss           | 11            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 36            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 0.00012293225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | -0.0264       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.46          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00128      |
# |    value_loss           | 11.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 37            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 4736          |
# | train/                  |               |
# |    approx_kl            | 0.00011578901 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.0361        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.8           |
# |    n_updates            | 144           |
# |    policy_gradient_loss | 0.000121      |
# |    value_loss           | 10.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 38            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 4864          |
# | train/                  |               |
# |    approx_kl            | 8.8223256e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.0856        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.04          |
# |    n_updates            | 148           |
# |    policy_gradient_loss | -0.000738     |
# |    value_loss           | 9.15          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 595          |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 39           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 4992         |
# | train/                  |              |
# |    approx_kl            | 8.800812e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.42         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 3.05e-05     |
# |    value_loss           | 8.43         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 595          |
# |    flag_rate_100        | 0            |
# |    mean_length_100      | 370          |
# |    mean_reward_100      | 595          |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 40           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 4.098518e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | -0.0103      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 584          |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00038     |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 370           |
# |    ep_rew_mean          | 595           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 41            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 5248          |
# | train/                  |               |
# |    approx_kl            | 8.8219065e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | -0.322        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.71          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 10.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 442           |
# |    ep_rew_mean          | 618           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 42            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 5376          |
# | train/                  |               |
# |    approx_kl            | 0.00018760096 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | -0.0117       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.58          |
# |    n_updates            | 164           |
# |    policy_gradient_loss | -0.00158      |
# |    value_loss           | 8.39          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 442           |
# |    ep_rew_mean          | 618           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 43            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 5504          |
# | train/                  |               |
# |    approx_kl            | 0.00012819702 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.00406       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.87e+03      |
# |    n_updates            | 168           |
# |    policy_gradient_loss | 0.00031       |
# |    value_loss           | 5.74e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 430           |
# |    ep_rew_mean          | 626           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 44            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 5.0515868e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.0352        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 728           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | 0.000756      |
# |    value_loss           | 1.46e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 430           |
# |    ep_rew_mean          | 626           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 45            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 5760          |
# | train/                  |               |
# |    approx_kl            | 2.4546403e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | 0.0294        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 734           |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 1.47e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 430           |
# |    ep_rew_mean          | 626           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 46            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 5888          |
# | train/                  |               |
# |    approx_kl            | 1.5586615e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | 0.0277        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.48e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 4.74e-05      |
# |    value_loss           | 4.97e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 430          |
# |    ep_rew_mean          | 626          |
# |    flag_rate_100        | 0            |
# |    mean_length_100      | 430          |
# |    mean_reward_100      | 626          |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 47           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 6016         |
# | train/                  |              |
# |    approx_kl            | 9.550713e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | -0.365       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.35         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000201    |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 438           |
# |    ep_rew_mean          | 651           |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 48            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00038343202 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | -0.00452      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 17.2          |
# |    n_updates            | 188           |
# |    policy_gradient_loss | -0.00353      |
# |    value_loss           | 34.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 438           |
# |    ep_rew_mean          | 651           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 49            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 6272          |
# | train/                  |               |
# |    approx_kl            | 0.00067588314 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | -0.00406      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.3e+03       |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 2.6e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 438           |
# |    ep_rew_mean          | 651           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 50            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 6400          |
# | train/                  |               |
# |    approx_kl            | 0.00031853514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.86         |
# |    explained_variance   | 0.00613       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.66e+03      |
# |    n_updates            | 196           |
# |    policy_gradient_loss | 0.00115       |
# |    value_loss           | 5.33e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 438           |
# |    ep_rew_mean          | 651           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 51            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 6528          |
# | train/                  |               |
# |    approx_kl            | 0.00021142978 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.85         |
# |    explained_variance   | 0.00796       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 195           |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00279      |
# |    value_loss           | 394           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 438           |
# |    ep_rew_mean          | 651           |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 52            |
# ...
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 175           |
# |    ep_rew_mean          | 799           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 664           |
# |    time_elapsed         | 725           |
# |    total_timesteps      | 84992         |
# | train/                  |               |
# |    approx_kl            | 5.6295656e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 0.000291      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 52.2          |
# |    n_updates            | 2652          |
# |    policy_gradient_loss | -0.000514     |
# |    value_loss           | 104           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 798          |
# |    flag_rate_100        | 0            |
# |    mean_length_100      | 175          |
# |    mean_reward_100      | 799          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 665          |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 85120        |
# | train/                  |              |
# |    approx_kl            | 5.631661e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 4.48e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.81e+03     |
# |    n_updates            | 2656         |
# |    policy_gradient_loss | 0.000283     |
# |    value_loss           | 5.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 798          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 666          |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 85248        |
# | train/                  |              |
# |    approx_kl            | 2.695201e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.26e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.39e+03     |
# |    n_updates            | 2660         |
# |    policy_gradient_loss | -6.19e-05    |
# |    value_loss           | 4.79e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 174           |
# |    ep_rew_mean          | 795           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 667           |
# |    time_elapsed         | 728           |
# |    total_timesteps      | 85376         |
# | train/                  |               |
# |    approx_kl            | 2.1893065e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.000736      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 895           |
# |    n_updates            | 2664          |
# |    policy_gradient_loss | -0.000274     |
# |    value_loss           | 1.79e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 174           |
# |    ep_rew_mean          | 795           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 668           |
# |    time_elapsed         | 729           |
# |    total_timesteps      | 85504         |
# | train/                  |               |
# |    approx_kl            | 1.7528422e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 2.68e-06      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.05e+03      |
# |    n_updates            | 2668          |
# |    policy_gradient_loss | -3.27e-05     |
# |    value_loss           | 6.11e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 812          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 669          |
# |    time_elapsed         | 730          |
# |    total_timesteps      | 85632        |
# | train/                  |              |
# |    approx_kl            | 4.578382e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 2.98e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.95e+03     |
# |    n_updates            | 2672         |
# |    policy_gradient_loss | 0.000234     |
# |    value_loss           | 1.19e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 812           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 670           |
# |    time_elapsed         | 731           |
# |    total_timesteps      | 85760         |
# | train/                  |               |
# |    approx_kl            | 2.3101456e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -4.41e-06     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.47e+03      |
# |    n_updates            | 2676          |
# |    policy_gradient_loss | -0.000148     |
# |    value_loss           | 4.94e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 812           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 671           |
# |    time_elapsed         | 732           |
# |    total_timesteps      | 85888         |
# | train/                  |               |
# |    approx_kl            | 2.9099174e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000383      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.51e+03      |
# |    n_updates            | 2680          |
# |    policy_gradient_loss | -0.000313     |
# |    value_loss           | 7.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 809           |
# |    flag_rate_100        | 0             |
# |    mean_length_100      | 176           |
# |    mean_reward_100      | 809           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 672           |
# |    time_elapsed         | 733           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.4465302e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000477      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 421           |
# |    n_updates            | 2684          |
# |    policy_gradient_loss | -0.000542     |
# |    value_loss           | 843           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 813          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 673          |
# |    time_elapsed         | 734          |
# |    total_timesteps      | 86144        |
# | train/                  |              |
# |    approx_kl            | 2.050167e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 1.4e-05      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.1e+03      |
# |    n_updates            | 2688         |
# |    policy_gradient_loss | -6.8e-06     |
# |    value_loss           | 6.2e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 818         |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 674         |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 86272       |
# | train/                  |             |
# |    approx_kl            | 7.99261e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.000187    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.01e+03    |
# |    n_updates            | 2692        |
# |    policy_gradient_loss | -2.31e-05   |
# |    value_loss           | 8.02e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 818          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 675          |
# |    time_elapsed         | 736          |
# |    total_timesteps      | 86400        |
# | train/                  |              |
# |    approx_kl            | 3.318768e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -1.67e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.91e+03     |
# |    n_updates            | 2696         |
# |    policy_gradient_loss | 7.04e-06     |
# |    value_loss           | 9.83e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 817           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 676           |
# |    time_elapsed         | 737           |
# |    total_timesteps      | 86528         |
# | train/                  |               |
# |    approx_kl            | 1.4025718e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.000579      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.24e+03      |
# |    n_updates            | 2700          |
# |    policy_gradient_loss | -6.52e-05     |
# |    value_loss           | 2.47e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 822          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 677          |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 86656        |
# | train/                  |              |
# |    approx_kl            | 2.606772e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 3.84e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 2704         |
# |    policy_gradient_loss | -4.29e-05    |
# |    value_loss           | 5.98e+03     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 177            |
# |    ep_rew_mean          | 822            |
# | time/                   |                |
# |    fps                  | 117            |
# |    iterations           | 678            |
# |    time_elapsed         | 739            |
# |    total_timesteps      | 86784          |
# | train/                  |                |
# |    approx_kl            | 1.16396695e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -1.39          |
# |    explained_variance   | 0.00036        |
# |    learning_rate        | 0.00025        |
# |    loss                 | 1.51e+03       |
# |    n_updates            | 2708           |
# |    policy_gradient_loss | -0.000484      |
# |    value_loss           | 3.02e+03       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 177           |
# |    ep_rew_mean          | 822           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 679           |
# |    time_elapsed         | 740           |
# |    total_timesteps      | 86912         |
# | train/                  |               |
# |    approx_kl            | 2.8972048e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.000247      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 546           |
# |    n_updates            | 2712          |
# |    policy_gradient_loss | -0.000358     |
# |    value_loss           | 1.09e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 178           |
# |    ep_rew_mean          | 820           |
# |    flag_rate_100        | 0             |
# |    mean_length_100      | 178           |
# |    mean_reward_100      | 820           |
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 680           |
# |    time_elapsed         | 741           |
# |    total_timesteps      | 87040         |
# | train/                  |               |
# |    approx_kl            | 6.5132044e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.000696      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 601           |
# |    n_updates            | 2716          |
# |    policy_gradient_loss | -2.85e-05     |
# |    value_loss           | 1.2e+03       |
# -------------------------------------------

# %%
# Quick test
from src.utils.evaluation import evaluate_agent
results = evaluate_agent(model, env, n_episodes=10)
print(f"Mean reward: {results['mean_reward']:.1f} ± {results['std_reward']:.1f}")
print(f"Flag rate: {results['flag_rate']:.2%}")
